# %% [markdown]
# # Face Detection using OpenCV

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('familyImage.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize = (20,10))
plt.imshow(image)

# %% [markdown]
# ## Convert image into gray scale
# To use a face detector, we'll first convert the image from color to grayscale.

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.figure(figsize = (20,10))
plt.imshow(gray,cmap ='gray')

# %% [markdown]
# ## Perform face detection using Haar cascades
#
# We load in the fully trained architecture of the face detector, found in [openCV github](https://github.com/opencv/opencv/tree/master/data/haarcascades)
#
# How many faces are detected is determined by the function, detectMultiScale which aims to detect faces of varying sizes. The inputs to this function are: (image, scaleFactor, minNeighbors); you will often detect more faces with a smaller scaleFactor, and lower value for minNeighbors, but raising these values often produces better matches. Modify these values depending on your input image.

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray,2,3)
print('Number of Detected Faces:', len(faces))
# Out:
# Number of Detected Faces: 5

# %%
image_with_detected_faces = np.copy(image)
for (x,y,w,h)in faces:
    cv2.rectangle(image_with_detected_faces,(x,y), (x+w,y+h), (255,0,0),5)
plt.figure(figsize = (20,10))
plt.imshow(image_with_detected_faces)
